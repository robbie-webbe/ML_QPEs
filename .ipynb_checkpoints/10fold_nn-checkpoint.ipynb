# %%
import numpy as np
import tensorflow as tf
from random import sample, shuffle

n = 10
feat_lists = []

#import the feature sets and split to features and labels
for i in range(n):
    feat_lists.append(np.loadtxt('Features/'+str(n)+'fold_cvsets/kfold_'+str(n)+'featuresets_set'+str(i)+'.csv',delimiter=','))
    
features_array = np.zeros((n,len(feat_lists[0]),14))
labels_array = np.zeros((n,len(feat_lists[0])))

#import the feature and label sets
for i in range(n):
    features_array[i,:,:] = feat_lists[i][:,0:-1]
    labels_array[i,:] = feat_lists[i][:,-1]

# %%
for i in range(n):
    #create the training data set
    training_feats = np.delete(features_array,i,0)
    training_feats = np.reshape(training_feats,(training_feats.shape[0]*training_feats.shape[1],training_feats.shape[2]))
    training_labels = np.delete(labels_array,i,0)
    training_labels = np.reshape(training_labels,(training_labels.shape[0]*training_labels.shape[1]))
    
    #extract the validation data set
    valid_feats = features_array[i]
    valid_labels = labels_array[i,:]
    
    print('Iteration '+str(i))
    #create and test models
    model = tf.keras.Sequential([tf.keras.layers.Dense(14, activation='relu'), tf.keras.layers.Dense(2)])
    model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    model.fit(training_feats, training_labels, epochs=10)
    test_loss, test_acc = model.evaluate(valid_feats, valid_labels, verbose=2)

    print('\nTest accuracy:', test_acc)
# Out:
# Iteration 0
# Epoch 1/10
# 2022-08-30 15:01:05.547944: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2813/2813 [==============================] - 3s 928us/step - loss: 0.4751 - accuracy: 0.8920
# Epoch 2/10
# 2813/2813 [==============================] - 2s 777us/step - loss: 0.3163 - accuracy: 0.9059
# Epoch 3/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.3081 - accuracy: 0.9094
# Epoch 4/10
# 2813/2813 [==============================] - 2s 801us/step - loss: 0.2949 - accuracy: 0.9130
# Epoch 5/10
# 2813/2813 [==============================] - 2s 798us/step - loss: 0.2926 - accuracy: 0.9135
# Epoch 6/10
# 2813/2813 [==============================] - 2s 819us/step - loss: 0.2969 - accuracy: 0.9143
# Epoch 7/10
# 2813/2813 [==============================] - 2s 822us/step - loss: 0.2894 - accuracy: 0.9142
# Epoch 8/10
# 2813/2813 [==============================] - 2s 801us/step - loss: 0.3014 - accuracy: 0.9139
# Epoch 9/10
# 2813/2813 [==============================] - 2s 814us/step - loss: 0.2913 - accuracy: 0.9154
# Epoch 10/10
# 2813/2813 [==============================] - 2s 879us/step - loss: 0.2843 - accuracy: 0.9169
# 313/313 - 0s - loss: 0.2065 - accuracy: 0.9350 - 354ms/epoch - 1ms/step
#
# Test accuracy: 0.9350000023841858
# Iteration 1
# Epoch 1/10
# 2813/2813 [==============================] - 3s 868us/step - loss: 1.9563 - accuracy: 0.8749
# Epoch 2/10
# 2813/2813 [==============================] - 3s 894us/step - loss: 0.3103 - accuracy: 0.9047
# Epoch 3/10
# 2813/2813 [==============================] - 2s 879us/step - loss: 0.2969 - accuracy: 0.9095
# Epoch 4/10
# 2813/2813 [==============================] - 2s 858us/step - loss: 0.3003 - accuracy: 0.9122
# Epoch 5/10
# 2813/2813 [==============================] - 3s 897us/step - loss: 0.3133 - accuracy: 0.9107
# Epoch 6/10
# 2813/2813 [==============================] - 2s 870us/step - loss: 0.2955 - accuracy: 0.9140
# Epoch 7/10
# 2813/2813 [==============================] - 2s 855us/step - loss: 0.2883 - accuracy: 0.9152
# Epoch 8/10
10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.3064 - accuracy: 0.9124
# Epoch 5/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2960 - accuracy: 0.9135
# Epoch 6/10
# 2813/2813 [==============================] - 2s 764us/step - loss: 0.2991 - accuracy: 0.9147
# Epoch 7/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.2989 - accuracy: 0.9147
# Epoch 8/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2938 - accuracy: 0.9158
# Epoch 9/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2964 - accuracy: 0.9151
# Epoch 10/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2859 - accuracy: 0.9183
# 313/313 - 0s - loss: 0.2568 - accuracy: 0.9305 - 259ms/epoch - 827us/step
#
# Test accuracy: 0.9304999709129333
# Iteration 8
# Epoch 1/10
# 2813/2813 [==============================] - 2s 760us/step - loss: 2.5698 - accuracy: 0.8494
# Epoch 2/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.3022 - accuracy: 0.9096
# Epoch 3/10
# 2813/2813 [==============================] - 2s 820us/step - loss: 0.2790 - accuracy: 0.9153
# Epoch 4/10
# 2813/2813 [==============================] - 2s 840us/step - loss: 0.2751 - accuracy: 0.9181
# Epoch 5/10
# 2813/2813 [==============================] - 2s 783us/step - loss: 0.2628 - accuracy: 0.9206
# Epoch 6/10
# 2813/2813 [==============================] - 2s 781us/step - loss: 0.2604 - accuracy: 0.9222
# Epoch 7/10
# 2813/2813 [==============================] - 2s 743us/step - loss: 0.2669 - accuracy: 0.9212
# Epoch 8/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.2614 - accuracy: 0.9217
# Epoch 9/10
# 2813/2813 [==============================] - 2s 744us/step - loss: 0.2524 - accuracy: 0.9235
# Epoch 10/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2448 - accuracy: 0.9248
# 313/313 - 0s - loss: 0.2257 - accuracy: 0.9300 - 255ms/epoch - 814us/step
#
# Test accuracy: 0.9300000071525574
# Iteration 9
# Epoch 1/10
# 2813/2813 [==============================] - 2s 756us/step - loss: 3.5242 - accuracy: 0.8909
# Epoch 2/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.2843 - accuracy: 0.9109
# Epoch 3/10
# 2813/2813 [==============================] - 2s 746us/step - loss: 0.2867 - accuracy: 0.9128
# Epoch 4/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.2716 - accuracy: 0.9176
# Epoch 5/10
# 2813/2813 [==============================] - 2s 755us/step - loss: 0.2650 - accuracy: 0.9194
# Epoch 6/10
# 2813/2813 [==============================] - 2s 771us/step - loss: 0.2621 - accuracy: 0.9206
# Epoch 7/10
# 2813/2813 [==============================] - 2s 767us/step - loss: 0.2545 - accuracy: 0.9230
# Epoch 8/10
# 2813/2813 [==============================] - 2s 763us/step - loss: 0.2686 - accuracy: 0.9211
# Epoch 9/10
# 2813/2813 [==============================] - 2s 766us/step - loss: 0.2658 - accuracy: 0.9225
# Epoch 10/10
# 2813/2813 [==============================] - 2s 762us/step - loss: 0.2594 - accuracy: 0.9234
# 313/313 - 0s - loss: 0.2383 - accuracy: 0.9310 - 269ms/epoch - 858us/step
#
# Test accuracy: 0.9309999942779541
