# %%
import numpy as np
import tensorflow as tf
from random import sample, shuffle

n = 10
feat_lists = []

#import the feature sets and split to features and labels
for i in range(n):
    feat_lists.append(np.loadtxt('Features/'+str(n)+'fold_cvsets/kfold_'+str(n)+'featuresets_set'+str(i)+'.csv',delimiter=','))
    
features_array = np.zeros((n,len(feat_lists[0]),14))
labels_array = np.zeros((n,len(feat_lists[0])))

#import the feature and label sets
for i in range(n):
    features_array[i,:,:] = feat_lists[i][:,0:-1]
    labels_array[i,:] = feat_lists[i][:,-1]

# %%
for i in range(n):
    #create the training data set
    training_feats = np.delete(features_array,i,0)
    training_feats = np.reshape(training_feats,(training_feats.shape[0]*training_feats.shape[1],training_feats.shape[2]))
    training_labels = np.delete(labels_array,i,0)
    training_labels = np.reshape(training_labels,(training_labels.shape[0]*training_labels.shape[1]))
    
    #extract the validation data set
    valid_feats = features_array[i]
    valid_labels = labels_array[i,:]
    
    print('Iteration '+str(i+1), '\n')
    #create and test models
    model = tf.keras.Sequential([tf.keras.layers.Dense(14, activation='relu'), tf.keras.layers.Dense(2)])
    model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    model.fit(training_feats, training_labels, epochs=10)
    test_loss, test_acc = model.evaluate(valid_feats, valid_labels, verbose=2)

    print('\nTest accuracy:', test_acc, '\n')
# Out:
# Iteration 1
#
# Epoch 1/10
# 2022-08-31 11:52:41.288110: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2813/2813 [==============================] - 2s 739us/step - loss: 6.8597 - accuracy: 0.8635
# Epoch 2/10
# 2813/2813 [==============================] - 2s 736us/step - loss: 0.2814 - accuracy: 0.9142
# Epoch 3/10
# 2813/2813 [==============================] - 2s 736us/step - loss: 0.2784 - accuracy: 0.9159
# Epoch 4/10
# 2813/2813 [==============================] - 2s 736us/step - loss: 0.2751 - accuracy: 0.9184
# Epoch 5/10
# 2813/2813 [==============================] - 2s 735us/step - loss: 0.2710 - accuracy: 0.9193
# Epoch 6/10
# 2813/2813 [==============================] - 2s 733us/step - loss: 0.2684 - accuracy: 0.9213
# Epoch 7/10
# 2813/2813 [==============================] - 2s 738us/step - loss: 0.2729 - accuracy: 0.9207
# Epoch 8/10
# 2813/2813 [==============================] - 2s 737us/step - loss: 0.2639 - accuracy: 0.9214
# Epoch 9/10
# 2813/2813 [==============================] - 2s 739us/step - loss: 0.2617 - accuracy: 0.9218
# Epoch 10/10
# 2813/2813 [==============================] - 2s 741us/step - loss: 0.2614 - accuracy: 0.9220
# 313/313 - 0s - loss: 0.2628 - accuracy: 0.8966 - 276ms/epoch - 881us/step
#
# Test accuracy: 0.8966000080108643
#
# Iteration 2
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 748us/step - loss: 0.6037 - accuracy: 0.8672
# Epoch 2/10
# 2813/2813 [==============================] - 2s 741us/step - loss: 0.3110 - accuracy: 0.9024
# Epoch 3/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.3089 - accuracy: 0.9073
# Epoch 4/10
# 2813/2813 [==============================] - 2s 745us/step - loss: 0.2981 - accuracy: 0.9112
# Epoch 5/10
# 2813/2813 [==============================] - 2s 741us/step - loss: 0.2954 - accuracy: 0.9112
# Epoch 6/10
# 2813/2813 [==============================] - 2s 743us/step - loss: 0.2878 - accuracy: 0.9140
# Epoch 7/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2846 - accuracy: 0.9151
# Epoch 8/10
# 2813/2813 [==============================] - 2s 746us/step - loss: 0.3003 - accuracy: 0.9127
# Epoch 9/10
# 2813/2813 [==============================] - 2s 744us/step - loss: 0.2880 - accuracy: 0.9159
# Epoch 10/10
# 2813/2813 [==============================] - 2s 744us/step - loss: 0.2812 - accuracy: 0.9167
# 313/313 - 0s - loss: 0.2545 - accuracy: 0.9032 - 252ms/epoch - 805us/step
#
# Test accuracy: 0.9031999707221985
#
# Iteration 3
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 781us/step - loss: 0.6637 - accuracy: 0.8870
# Epoch 2/10
# 2813/2813 [==============================] - 2s 756us/step - loss: 0.2830 - accuracy: 0.9108
# Epoch 3/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2761 - accuracy: 0.9147
# Epoch 4/10
# 2813/2813 [==============================] - 2s 747us/step - loss: 0.2648 - accuracy: 0.9181
# Epoch 5/10
# 2813/2813 [==============================] - 2s 751us/step - loss: 0.2655 - accuracy: 0.9183
# Epoch 6/10
# 2813/2813 [==============================] - 2s 748us/step - loss: 0.2526 - accuracy: 0.9217
# Epoch 7/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2530 - accuracy: 0.9220
# Epoch 8/10
# 2813/2813 [==============================] - 2s 747us/step - loss: 0.2500 - accuracy: 0.9226
# Epoch 9/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2547 - accuracy: 0.9223
# Epoch 10/10
# 2813/2813 [==============================] - 2s 758us/step - loss: 0.2513 - accuracy: 0.9233
# 313/313 - 0s - loss: 0.3112 - accuracy: 0.9272 - 252ms/epoch - 804us/step
#
# Test accuracy: 0.9272000193595886
#
# Iteration 4
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 783us/step - loss: 0.9776 - accuracy: 0.8913
# Epoch 2/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2919 - accuracy: 0.9120
# Epoch 3/10
# 2813/2813 [==============================] - 2s 751us/step - loss: 0.3010 - accuracy: 0.9131
# Epoch 4/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.2906 - accuracy: 0.9168
# Epoch 5/10
# 2813/2813 [==============================] - 2s 772us/step - loss: 0.2895 - accuracy: 0.9166
# Epoch 6/10
# 2813/2813 [==============================] - 2s 791us/step - loss: 0.2763 - accuracy: 0.9187
# Epoch 7/10
# 2813/2813 [==============================] - 2s 759us/step - loss: 0.2737 - accuracy: 0.9199
# Epoch 8/10
# 2813/2813 [==============================] - 2s 762us/step - loss: 0.2778 - accuracy: 0.9202
# Epoch 9/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2742 - accuracy: 0.9215
# Epoch 10/10
# 2813/2813 [==============================] - 2s 759us/step - loss: 0.2616 - accuracy: 0.9225
# 313/313 - 0s - loss: 0.2560 - accuracy: 0.9311 - 255ms/epoch - 814us/step
#
# Test accuracy: 0.9311000108718872
#
# Iteration 5
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 769us/step - loss: 3.1347 - accuracy: 0.8889
# Epoch 2/10
# 2813/2813 [==============================] - 2s 759us/step - loss: 0.2894 - accuracy: 0.9090
# Epoch 3/10
# 2813/2813 [==============================] - 2s 756us/step - loss: 0.2852 - accuracy: 0.9133
# Epoch 4/10
# 2813/2813 [==============================] - 2s 751us/step - loss: 0.2818 - accuracy: 0.9147
# Epoch 5/10
# 2813/2813 [==============================] - 2s 759us/step - loss: 0.2722 - accuracy: 0.9162
# Epoch 6/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2650 - accuracy: 0.9188
# Epoch 7/10
# 2813/2813 [==============================] - 2s 764us/step - loss: 0.2695 - accuracy: 0.9189
# Epoch 8/10
# 2813/2813 [==============================] - 2s 781us/step - loss: 0.2642 - accuracy: 0.9210
# Epoch 9/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2703 - accuracy: 0.9202
# Epoch 10/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.2680 - accuracy: 0.9211
# 313/313 - 0s - loss: 0.2959 - accuracy: 0.9278 - 248ms/epoch - 792us/step
#
# Test accuracy: 0.9277999997138977
#
# Iteration 6
#
# Epoch 1/10
# 2813/2813 [==============================] - 3s 797us/step - loss: 1.1956 - accuracy: 0.8702
# Epoch 2/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2946 - accuracy: 0.9108
# Epoch 3/10
# 2813/2813 [==============================] - 2s 763us/step - loss: 0.2897 - accuracy: 0.9133
# Epoch 4/10
# 2813/2813 [==============================] - 2s 778us/step - loss: 0.2794 - accuracy: 0.9167
# Epoch 5/10
# 2813/2813 [==============================] - 2s 774us/step - loss: 0.2853 - accuracy: 0.9164
# Epoch 6/10
# 2813/2813 [==============================] - 2s 758us/step - loss: 0.2723 - accuracy: 0.9192
# Epoch 7/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.2774 - accuracy: 0.9181
# Epoch 8/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.2703 - accuracy: 0.9200
# Epoch 9/10
# 2813/2813 [==============================] - 2s 753us/step - loss: 0.2673 - accuracy: 0.9204
# Epoch 10/10
# 2813/2813 [==============================] - 2s 751us/step - loss: 0.2666 - accuracy: 0.9206
# 313/313 - 0s - loss: 0.3402 - accuracy: 0.9248 - 249ms/epoch - 794us/step
#
# Test accuracy: 0.9247999787330627
#
# Iteration 7
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 785us/step - loss: 2.7538 - accuracy: 0.8865
# Epoch 2/10
# 2813/2813 [==============================] - 2s 782us/step - loss: 0.2836 - accuracy: 0.9112
# Epoch 3/10
# 2813/2813 [==============================] - 2s 793us/step - loss: 0.2710 - accuracy: 0.9172
# Epoch 4/10
# 2813/2813 [==============================] - 2s 808us/step - loss: 0.2727 - accuracy: 0.9179
# Epoch 5/10
# 2813/2813 [==============================] - 2s 765us/step - loss: 0.2625 - accuracy: 0.9201
# Epoch 6/10
# 2813/2813 [==============================] - 2s 761us/step - loss: 0.2584 - accuracy: 0.9213
# Epoch 7/10
# 2813/2813 [==============================] - 2s 760us/step - loss: 0.2546 - accuracy: 0.9226
# Epoch 8/10
# 2813/2813 [==============================] - 2s 760us/step - loss: 0.2511 - accuracy: 0.9236
# Epoch 9/10
# 2813/2813 [==============================] - 2s 766us/step - loss: 0.2517 - accuracy: 0.9239
# Epoch 10/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2487 - accuracy: 0.9245
# 313/313 - 0s - loss: 0.2491 - accuracy: 0.9309 - 250ms/epoch - 797us/step
#
# Test accuracy: 0.930899977684021
#
# Iteration 8
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.6408 - accuracy: 0.8930
# Epoch 2/10
# 2813/2813 [==============================] - 2s 761us/step - loss: 0.2770 - accuracy: 0.9108
# Epoch 3/10
# 2813/2813 [==============================] - 2s 741us/step - loss: 0.2797 - accuracy: 0.9130
# Epoch 4/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.2712 - accuracy: 0.9164
# Epoch 5/10
# 2813/2813 [==============================] - 2s 746us/step - loss: 0.2590 - accuracy: 0.9201
# Epoch 6/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.2563 - accuracy: 0.9207
# Epoch 7/10
# 2813/2813 [==============================] - 2s 747us/step - loss: 0.2590 - accuracy: 0.9202
# Epoch 8/10
# 2813/2813 [==============================] - 2s 748us/step - loss: 0.2517 - accuracy: 0.9226
# Epoch 9/10
# 2813/2813 [==============================] - 2s 740us/step - loss: 0.2448 - accuracy: 0.9243
# Epoch 10/10
# 2813/2813 [==============================] - 2s 742us/step - loss: 0.2390 - accuracy: 0.9260
# 313/313 - 0s - loss: 0.2404 - accuracy: 0.9294 - 248ms/epoch - 791us/step
#
# Test accuracy: 0.9294000267982483
#
# Iteration 9
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 784us/step - loss: 5.1028 - accuracy: 0.8861
# Epoch 2/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.2982 - accuracy: 0.9092
# Epoch 3/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2919 - accuracy: 0.9116
# Epoch 4/10
# 2813/2813 [==============================] - 2s 758us/step - loss: 0.2866 - accuracy: 0.9140
# Epoch 5/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2863 - accuracy: 0.9146
# Epoch 6/10
# 2813/2813 [==============================] - 2s 751us/step - loss: 0.2779 - accuracy: 0.9175
# Epoch 7/10
# 2813/2813 [==============================] - 2s 763us/step - loss: 0.2728 - accuracy: 0.9182
# Epoch 8/10
# 2813/2813 [==============================] - 2s 749us/step - loss: 0.2699 - accuracy: 0.9191
# Epoch 9/10
# 2813/2813 [==============================] - 2s 750us/step - loss: 0.2731 - accuracy: 0.9188
# Epoch 10/10
# 2813/2813 [==============================] - 2s 752us/step - loss: 0.2727 - accuracy: 0.9191
# 313/313 - 0s - loss: 0.2525 - accuracy: 0.9301 - 252ms/epoch - 804us/step
#
# Test accuracy: 0.9301000237464905
#
# Iteration 10
#
# Epoch 1/10
# 2813/2813 [==============================] - 2s 771us/step - loss: 0.8964 - accuracy: 0.8854
# Epoch 2/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.3058 - accuracy: 0.9084
# Epoch 3/10
# 2813/2813 [==============================] - 2s 763us/step - loss: 0.3007 - accuracy: 0.9126
# Epoch 4/10
# 2813/2813 [==============================] - 2s 756us/step - loss: 0.2885 - accuracy: 0.9160
# Epoch 5/10
# 2813/2813 [==============================] - 2s 754us/step - loss: 0.2815 - accuracy: 0.9168
# Epoch 6/10
# 2813/2813 [==============================] - 2s 758us/step - loss: 0.2865 - accuracy: 0.9171
# Epoch 7/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2842 - accuracy: 0.9190
# Epoch 8/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2773 - accuracy: 0.9191
# Epoch 9/10
# 2813/2813 [==============================] - 2s 753us/step - loss: 0.2845 - accuracy: 0.9196
# Epoch 10/10
# 2813/2813 [==============================] - 2s 757us/step - loss: 0.2692 - accuracy: 0.9215
# 313/313 - 0s - loss: 0.2273 - accuracy: 0.9316 - 256ms/epoch - 817us/step
#
# Test accuracy: 0.9315999746322632
