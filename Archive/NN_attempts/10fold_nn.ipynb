# %%
import numpy as np
import tensorflow as tf
from random import sample, shuffle

n = 10
feat_lists = []

#import the feature sets and split to features and labels
for i in range(n):
    feat_lists.append(np.loadtxt('Features/'+str(n)+'fold_cvsets/kfold_'+str(n)+'featuresets_set'+str(i)+'.csv',delimiter=','))
    
features_array = np.zeros((n,len(feat_lists[0]),14))
labels_array = np.zeros((n,len(feat_lists[0])))

#import the feature and label sets
for i in range(n):
    features_array[i,:,:] = feat_lists[i][:,0:-1]
    labels_array[i,:] = feat_lists[i][:,-1]

# %%
for i in range(n):
    #create the training data set
    training_feats = np.delete(features_array,i,0)
    training_feats = np.reshape(training_feats,(training_feats.shape[0]*training_feats.shape[1],training_feats.shape[2]))
    training_labels = np.delete(labels_array,i,0)
    training_labels = np.reshape(training_labels,(training_labels.shape[0]*training_labels.shape[1]))
    
    #extract the validation data set
    valid_feats = features_array[i]
    valid_labels = labels_array[i,:]
    
    print('Iteration '+str(i+1), '\n')
    print('Training data: QPE - '+ str(np.count_nonzero(training_labels == 1)) + '. No QPE - '+ str(np.count_nonzero(training_labels == 0)) + '.')
    print('Validation data: QPE - '+ str(np.count_nonzero(valid_labels == 1)) + '. No QPE - '+ str(np.count_nonzero(valid_labels == 0)) + '. \n')
    
    #create and test models
    model = tf.keras.Sequential([tf.keras.layers.Dense(14, activation='relu'), tf.keras.layers.Dense(2)])
    model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    model.fit(training_feats, training_labels, epochs=10)
    test_loss, test_acc = model.evaluate(valid_feats, valid_labels, verbose=2)

    print('\nTest accuracy:', test_acc, '\n')
# Out:
# Iteration 1
#
# Training data: QPE - 40509. No QPE - 40491.
# Validation data: QPE - 4491. No QPE - 4509.
#
# Epoch 1/10
# 2022-09-01 11:51:34.614105: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2532/2532 [==============================] - 2s 715us/step - loss: 0.8677 - accuracy: 0.8878
# Epoch 2/10
# 2532/2532 [==============================] - 2s 724us/step - loss: 0.2822 - accuracy: 0.9134
# Epoch 3/10
# 2532/2532 [==============================] - 2s 836us/step - loss: 0.2817 - accuracy: 0.9160
# Epoch 4/10
# 2532/2532 [==============================] - 2s 793us/step - loss: 0.2718 - accuracy: 0.9186
# Epoch 5/10
# 2532/2532 [==============================] - 2s 749us/step - loss: 0.2656 - accuracy: 0.9201
# Epoch 6/10
# 2532/2532 [==============================] - 2s 757us/step - loss: 0.2670 - accuracy: 0.9204
# Epoch 7/10
# 2532/2532 [==============================] - 2s 768us/step - loss: 0.2605 - accuracy: 0.9214
# Epoch 8/10
# 2532/2532 [==============================] - 2s 773us/step - loss: 0.2551 - accuracy: 0.9229
# Epoch 9/10
# 2532/2532 [==============================] - 2s 764us/step - loss: 0.2592 - accuracy: 0.9220
# Epoch 10/10
# 2532/2532 [==============================] - 2s 773us/step - loss: 0.2465 - accuracy: 0.9245
# 282/282 - 0s - loss: 0.2467 - accuracy: 0.9297 - 264ms/epoch - 937us/step
#
# Test accuracy: 0.9296666383743286
#
# Iteration 2
#
# Training data: QPE - 40545. No QPE - 40455.
# Validation data: QPE - 4455. No QPE - 4545.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 778us/step - loss: 0.7710 - accuracy: 0.8794
# Epoch 2/10
# 2532/2532 [==============================] - 2s 784us/step - loss: 0.2940 - accuracy: 0.9079
# Epoch 3/10
# 2532/2532 [==============================] - 2s 774us/step - loss: 0.2830 - accuracy: 0.9135
# Epoch 4/10
# 2532/2532 [==============================] - 2s 784us/step - loss: 0.2810 - accuracy: 0.9154
# Epoch 5/10
# 2532/2532 [==============================] - 2s 776us/step - loss: 0.2877 - accuracy: 0.9154
# Epoch 6/10
# 2532/2532 [==============================] - 2s 743us/step - loss: 0.2732 - accuracy: 0.9179
# Epoch 7/10
# 2532/2532 [==============================] - 2s 770us/step - loss: 0.2681 - accuracy: 0.9190
# Epoch 8/10
# 2532/2532 [==============================] - 2s 761us/step - loss: 0.2786 - accuracy: 0.9177
# Epoch 9/10
# 2532/2532 [==============================] - 2s 825us/step - loss: 0.2653 - accuracy: 0.9201
# Epoch 10/10
# 2532/2532 [==============================] - 2s 768us/step - loss: 0.2733 - accuracy: 0.9199
# 282/282 - 0s - loss: 0.2504 - accuracy: 0.9309 - 264ms/epoch - 936us/step
#
# Test accuracy: 0.9308888912200928
#
# Iteration 3
#
# Training data: QPE - 40459. No QPE - 40541.
# Validation data: QPE - 4541. No QPE - 4459.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 759us/step - loss: 0.7263 - accuracy: 0.8736
# Epoch 2/10
# 2532/2532 [==============================] - 2s 776us/step - loss: 0.2894 - accuracy: 0.9100
# Epoch 3/10
# 2532/2532 [==============================] - 2s 749us/step - loss: 0.2922 - accuracy: 0.9114
# Epoch 4/10
# 2532/2532 [==============================] - 2s 738us/step - loss: 0.2917 - accuracy: 0.9138
# Epoch 5/10
# 2532/2532 [==============================] - 2s 764us/step - loss: 0.2815 - accuracy: 0.9152
# Epoch 6/10
# 2532/2532 [==============================] - 2s 789us/step - loss: 0.2741 - accuracy: 0.9168
# Epoch 7/10
# 2532/2532 [==============================] - 2s 751us/step - loss: 0.2785 - accuracy: 0.9174
# Epoch 8/10
# 2532/2532 [==============================] - 2s 755us/step - loss: 0.2762 - accuracy: 0.9182
# Epoch 9/10
# 2532/2532 [==============================] - 2s 767us/step - loss: 0.2693 - accuracy: 0.9197
# Epoch 10/10
# 2532/2532 [==============================] - 2s 781us/step - loss: 0.2731 - accuracy: 0.9190
# 282/282 - 0s - loss: 0.2967 - accuracy: 0.9314 - 258ms/epoch - 916us/step
#
# Test accuracy: 0.9314444661140442
#
# Iteration 4
#
# Training data: QPE - 40544. No QPE - 40456.
# Validation data: QPE - 4456. No QPE - 4544.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 805us/step - loss: 5.2306 - accuracy: 0.8742
# Epoch 2/10
# 2532/2532 [==============================] - 2s 783us/step - loss: 0.2579 - accuracy: 0.9187
# Epoch 3/10
# 2532/2532 [==============================] - 2s 778us/step - loss: 0.2514 - accuracy: 0.9205
# Epoch 4/10
# 2532/2532 [==============================] - 2s 766us/step - loss: 0.2427 - accuracy: 0.9237
# Epoch 5/10
# 2532/2532 [==============================] - 2s 777us/step - loss: 0.2413 - accuracy: 0.9240
# Epoch 6/10
# 2532/2532 [==============================] - 2s 777us/step - loss: 0.2395 - accuracy: 0.9246
# Epoch 7/10
# 2532/2532 [==============================] - 2s 770us/step - loss: 0.2360 - accuracy: 0.9255
# Epoch 8/10
# 2532/2532 [==============================] - 2s 813us/step - loss: 0.2369 - accuracy: 0.9261
# Epoch 9/10
# 2532/2532 [==============================] - 2s 805us/step - loss: 0.2304 - accuracy: 0.9270
# Epoch 10/10
# 2532/2532 [==============================] - 2s 775us/step - loss: 0.2287 - accuracy: 0.9269
# 282/282 - 0s - loss: 0.2134 - accuracy: 0.9288 - 275ms/epoch - 975us/step
#
# Test accuracy: 0.9287777543067932
#
# Iteration 5
#
# Training data: QPE - 40468. No QPE - 40532.
# Validation data: QPE - 4532. No QPE - 4468.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 786us/step - loss: 0.4648 - accuracy: 0.8860
# Epoch 2/10
# 2532/2532 [==============================] - 2s 774us/step - loss: 0.3070 - accuracy: 0.9063
# Epoch 3/10
# 2532/2532 [==============================] - 2s 785us/step - loss: 0.3044 - accuracy: 0.9091
# Epoch 4/10
# 2532/2532 [==============================] - 2s 758us/step - loss: 0.3037 - accuracy: 0.9098
# Epoch 5/10
# 2532/2532 [==============================] - 2s 806us/step - loss: 0.2892 - accuracy: 0.9140
# Epoch 6/10
# 2532/2532 [==============================] - 2s 762us/step - loss: 0.3025 - accuracy: 0.9125
# Epoch 7/10
# 2532/2532 [==============================] - 2s 792us/step - loss: 0.2935 - accuracy: 0.9141
# Epoch 8/10
# 2532/2532 [==============================] - 2s 815us/step - loss: 0.2969 - accuracy: 0.9150
# Epoch 9/10
# 2532/2532 [==============================] - 2s 807us/step - loss: 0.2907 - accuracy: 0.9160
# Epoch 10/10
# 2532/2532 [==============================] - 2s 789us/step - loss: 0.2949 - accuracy: 0.9148
# 282/282 - 0s - loss: 0.2313 - accuracy: 0.9340 - 248ms/epoch - 879us/step
#
# Test accuracy: 0.9340000152587891
#
# Iteration 6
#
# Training data: QPE - 40524. No QPE - 40476.
# Validation data: QPE - 4476. No QPE - 4524.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 796us/step - loss: 0.4065 - accuracy: 0.8932
# Epoch 2/10
# 2532/2532 [==============================] - 2s 780us/step - loss: 0.2908 - accuracy: 0.9089
# Epoch 3/10
# 2532/2532 [==============================] - 2s 778us/step - loss: 0.2931 - accuracy: 0.9109
# Epoch 4/10
# 2532/2532 [==============================] - 2s 781us/step - loss: 0.2859 - accuracy: 0.9134
# Epoch 5/10
# 2532/2532 [==============================] - 2s 758us/step - loss: 0.2748 - accuracy: 0.9172
# Epoch 6/10
# 2532/2532 [==============================] - 2s 758us/step - loss: 0.2786 - accuracy: 0.9169
# Epoch 7/10
# 2532/2532 [==============================] - 2s 807us/step - loss: 0.2806 - accuracy: 0.9158
# Epoch 8/10
# 2532/2532 [==============================] - 2s 833us/step - loss: 0.2743 - accuracy: 0.9176
# Epoch 9/10
# 2532/2532 [==============================] - 2s 786us/step - loss: 0.2726 - accuracy: 0.9188
# Epoch 10/10
# 2532/2532 [==============================] - 2s 783us/step - loss: 0.2664 - accuracy: 0.9201
# 282/282 - 0s - loss: 0.3025 - accuracy: 0.8784 - 243ms/epoch - 863us/step
#
# Test accuracy: 0.8784444332122803
#
# Iteration 7
#
# Training data: QPE - 40500. No QPE - 40500.
# Validation data: QPE - 4500. No QPE - 4500.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 783us/step - loss: 2.3312 - accuracy: 0.8817
# Epoch 2/10
# 2532/2532 [==============================] - 2s 762us/step - loss: 0.2826 - accuracy: 0.9119
# Epoch 3/10
# 2532/2532 [==============================] - 2s 773us/step - loss: 0.2864 - accuracy: 0.9130
# Epoch 4/10
# 2532/2532 [==============================] - 2s 781us/step - loss: 0.2759 - accuracy: 0.9156
# Epoch 5/10
# 2532/2532 [==============================] - 2s 759us/step - loss: 0.2702 - accuracy: 0.9182
# Epoch 6/10
# 2532/2532 [==============================] - 2s 762us/step - loss: 0.2775 - accuracy: 0.9169
# Epoch 7/10
# 2532/2532 [==============================] - 2s 811us/step - loss: 0.2680 - accuracy: 0.9194
# Epoch 8/10
# 2532/2532 [==============================] - 2s 784us/step - loss: 0.2761 - accuracy: 0.9179
# Epoch 9/10
# 2532/2532 [==============================] - 2s 782us/step - loss: 0.2679 - accuracy: 0.9193
# Epoch 10/10
# 2532/2532 [==============================] - 2s 775us/step - loss: 0.2651 - accuracy: 0.9206
# 282/282 - 0s - loss: 0.4080 - accuracy: 0.9192 - 249ms/epoch - 884us/step
#
# Test accuracy: 0.9192222356796265
#
# Iteration 8
#
# Training data: QPE - 40487. No QPE - 40513.
# Validation data: QPE - 4513. No QPE - 4487.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 766us/step - loss: 4.1601 - accuracy: 0.8733
# Epoch 2/10
# 2532/2532 [==============================] - 2s 814us/step - loss: 0.2862 - accuracy: 0.9099
# Epoch 3/10
# 2532/2532 [==============================] - 2s 791us/step - loss: 0.2981 - accuracy: 0.9101
# Epoch 4/10
# 2532/2532 [==============================] - 2s 802us/step - loss: 0.2871 - accuracy: 0.9131
# Epoch 5/10
# 2532/2532 [==============================] - 2s 847us/step - loss: 0.2881 - accuracy: 0.9137
# Epoch 6/10
# 2532/2532 [==============================] - 2s 787us/step - loss: 0.2861 - accuracy: 0.9143
# Epoch 7/10
# 2532/2532 [==============================] - 2s 782us/step - loss: 0.2809 - accuracy: 0.9160
# Epoch 8/10
# 2532/2532 [==============================] - 2s 857us/step - loss: 0.2719 - accuracy: 0.9179
# Epoch 9/10
# 2532/2532 [==============================] - 2s 787us/step - loss: 0.2687 - accuracy: 0.9195
# Epoch 10/10
# 2532/2532 [==============================] - 2s 784us/step - loss: 0.2710 - accuracy: 0.9197
# 282/282 - 0s - loss: 0.2290 - accuracy: 0.9259 - 259ms/epoch - 919us/step
#
# Test accuracy: 0.9258888959884644
#
# Iteration 9
#
# Training data: QPE - 40484. No QPE - 40516.
# Validation data: QPE - 4516. No QPE - 4484.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 760us/step - loss: 0.6851 - accuracy: 0.8688
# Epoch 2/10
# 2532/2532 [==============================] - 2s 782us/step - loss: 0.2875 - accuracy: 0.9082
# Epoch 3/10
# 2532/2532 [==============================] - 2s 784us/step - loss: 0.2874 - accuracy: 0.9117
# Epoch 4/10
# 2532/2532 [==============================] - 2s 793us/step - loss: 0.2756 - accuracy: 0.9156
# Epoch 5/10
# 2532/2532 [==============================] - 2s 755us/step - loss: 0.2797 - accuracy: 0.9146
# Epoch 6/10
# 2532/2532 [==============================] - 2s 752us/step - loss: 0.2685 - accuracy: 0.9175
# Epoch 7/10
# 2532/2532 [==============================] - 2s 751us/step - loss: 0.2626 - accuracy: 0.9199
# Epoch 8/10
# 2532/2532 [==============================] - 2s 754us/step - loss: 0.2651 - accuracy: 0.9184
# Epoch 9/10
# 2532/2532 [==============================] - 2s 759us/step - loss: 0.2623 - accuracy: 0.9195
# Epoch 10/10
# 2532/2532 [==============================] - 2s 776us/step - loss: 0.2611 - accuracy: 0.9210
# 282/282 - 0s - loss: 0.2714 - accuracy: 0.9261 - 237ms/epoch - 841us/step
#
# Test accuracy: 0.926111102104187
#
# Iteration 10
#
# Training data: QPE - 40480. No QPE - 40520.
# Validation data: QPE - 4520. No QPE - 4480.
#
# Epoch 1/10
# 2532/2532 [==============================] - 2s 783us/step - loss: 2.0223 - accuracy: 0.8702
# Epoch 2/10
# 2532/2532 [==============================] - 2s 761us/step - loss: 0.2800 - accuracy: 0.9114
# Epoch 3/10
# 2532/2532 [==============================] - 2s 756us/step - loss: 0.2765 - accuracy: 0.9139
# Epoch 4/10
# 2532/2532 [==============================] - 2s 755us/step - loss: 0.2800 - accuracy: 0.9151
# Epoch 5/10
# 2532/2532 [==============================] - 2s 755us/step - loss: 0.2682 - accuracy: 0.9182
# Epoch 6/10
# 2532/2532 [==============================] - 2s 756us/step - loss: 0.2731 - accuracy: 0.9179
# Epoch 7/10
# 2532/2532 [==============================] - 2s 760us/step - loss: 0.2578 - accuracy: 0.9215
# Epoch 8/10
# 2532/2532 [==============================] - 2s 754us/step - loss: 0.2595 - accuracy: 0.9208
# Epoch 9/10
# 2532/2532 [==============================] - 2s 756us/step - loss: 0.2519 - accuracy: 0.9231
# Epoch 10/10
# 2532/2532 [==============================] - 2s 755us/step - loss: 0.2533 - accuracy: 0.9230
# 282/282 - 0s - loss: 0.2278 - accuracy: 0.9331 - 236ms/epoch - 836us/step
#
# Test accuracy: 0.9331111311912537
