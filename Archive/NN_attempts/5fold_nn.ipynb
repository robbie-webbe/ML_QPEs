# %%
import numpy as np
import tensorflow as tf
from random import sample, shuffle

n = 5 
feat_lists = []

#import the feature sets and split to features and labels
for i in range(n):
    feat_lists.append(np.loadtxt('Features/'+str(n)+'fold_cvsets/kfold_'+str(n)+'featuresets_set'+str(i)+'.csv',delimiter=','))
    
features_array = np.zeros((n,len(feat_lists[0]),14))
labels_array = np.zeros((n,len(feat_lists[0])))

#import the feature and label sets
for i in range(n):
    features_array[i,:,:] = feat_lists[i][:,0:-1]
    labels_array[i,:] = feat_lists[i][:,-1]

# %%
for i in range(n):
    #create the training data set
    training_feats = np.delete(features_array,i,0)
    training_feats = np.reshape(training_feats,(training_feats.shape[0]*training_feats.shape[1],training_feats.shape[2]))
    training_labels = np.delete(labels_array,i,0)
    training_labels = np.reshape(training_labels,(training_labels.shape[0]*training_labels.shape[1]))
    
    #extract the validation data set
    valid_feats = features_array[i]
    valid_labels = labels_array[i,:]
    
    print('Iteration '+str(i+1), '\n')
    print('Training data: QPE - '+ str(np.count_nonzero(training_labels == 1)) + '. No QPE - '+ str(np.count_nonzero(training_labels == 0)) + '.')
    print('Validation data: QPE - '+ str(np.count_nonzero(valid_labels == 1)) + '. No QPE - '+ str(np.count_nonzero(valid_labels == 0)) + '. \n')
    
    #create and test models
    model = tf.keras.Sequential([tf.keras.layers.Dense(14, activation='relu'), tf.keras.layers.Dense(2)])
    model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    model.fit(training_feats, training_labels, epochs=10)
    test_loss, test_acc = model.evaluate(valid_feats, valid_labels, verbose=2)

    print('\nTest accuracy:', test_acc, '\n')
# Out:
# Iteration 1
#
# Training data: QPE - 36082. No QPE - 35918.
# Validation data: QPE - 8918. No QPE - 9082.
#
# Epoch 1/10
# 2022-09-01 11:46:24.123175: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2250/2250 [==============================] - 2s 688us/step - loss: 4.9895 - accuracy: 0.8740
# Epoch 2/10
# 2250/2250 [==============================] - 2s 676us/step - loss: 0.2844 - accuracy: 0.9118
# Epoch 3/10
# 2250/2250 [==============================] - 2s 680us/step - loss: 0.2834 - accuracy: 0.9125
# Epoch 4/10
# 2250/2250 [==============================] - 2s 681us/step - loss: 0.2850 - accuracy: 0.9140
# Epoch 5/10
# 2250/2250 [==============================] - 2s 683us/step - loss: 0.2820 - accuracy: 0.9143
# Epoch 6/10
# 2250/2250 [==============================] - 2s 694us/step - loss: 0.2776 - accuracy: 0.9163
# Epoch 7/10
# 2250/2250 [==============================] - 2s 706us/step - loss: 0.2760 - accuracy: 0.9176
# Epoch 8/10
# 2250/2250 [==============================] - 2s 703us/step - loss: 0.2800 - accuracy: 0.9174
# Epoch 9/10
# 2250/2250 [==============================] - 2s 724us/step - loss: 0.2649 - accuracy: 0.9201
# Epoch 10/10
# 2250/2250 [==============================] - 2s 710us/step - loss: 0.2766 - accuracy: 0.9182
# 563/563 - 0s - loss: 0.2304 - accuracy: 0.9341 - 414ms/epoch - 735us/step
#
# Test accuracy: 0.9340555667877197
#
# Iteration 2
#
# Training data: QPE - 36131. No QPE - 35869.
# Validation data: QPE - 8869. No QPE - 9131.
#
# Epoch 1/10
# 2250/2250 [==============================] - 2s 738us/step - loss: 2.3801 - accuracy: 0.8828
# Epoch 2/10
# 2250/2250 [==============================] - 2s 714us/step - loss: 0.3067 - accuracy: 0.9062
# Epoch 3/10
# 2250/2250 [==============================] - 2s 717us/step - loss: 0.3105 - accuracy: 0.9085
# Epoch 4/10
# 2250/2250 [==============================] - 2s 714us/step - loss: 0.3100 - accuracy: 0.9097
# Epoch 5/10
# 2250/2250 [==============================] - 2s 810us/step - loss: 0.3033 - accuracy: 0.9103
# Epoch 6/10
# 2250/2250 [==============================] - 2s 784us/step - loss: 0.2953 - accuracy: 0.9130
# Epoch 7/10
# 2250/2250 [==============================] - 2s 748us/step - loss: 0.2963 - accuracy: 0.9134
# Epoch 8/10
# 2250/2250 [==============================] - 2s 726us/step - loss: 0.2892 - accuracy: 0.9156
# Epoch 9/10
# 2250/2250 [==============================] - 2s 723us/step - loss: 0.2914 - accuracy: 0.9147
# Epoch 10/10
# 2250/2250 [==============================] - 2s 735us/step - loss: 0.2775 - accuracy: 0.9168
# 563/563 - 0s - loss: 0.3183 - accuracy: 0.8606 - 399ms/epoch - 709us/step
#
# Test accuracy: 0.8605555295944214
#
# Iteration 3
#
# Training data: QPE - 36037. No QPE - 35963.
# Validation data: QPE - 8963. No QPE - 9037.
#
# Epoch 1/10
# 2250/2250 [==============================] - 2s 736us/step - loss: 1.1804 - accuracy: 0.8929
# Epoch 2/10
# 2250/2250 [==============================] - 2s 750us/step - loss: 0.2698 - accuracy: 0.9137
# Epoch 3/10
# 2250/2250 [==============================] - 2s 828us/step - loss: 0.2771 - accuracy: 0.9141
# Epoch 4/10
# 2250/2250 [==============================] - 2s 780us/step - loss: 0.2628 - accuracy: 0.9187
# Epoch 5/10
# 2250/2250 [==============================] - 2s 735us/step - loss: 0.2607 - accuracy: 0.9201
# Epoch 6/10
# 2250/2250 [==============================] - 2s 717us/step - loss: 0.2636 - accuracy: 0.9190
# Epoch 7/10
# 2250/2250 [==============================] - 2s 735us/step - loss: 0.2604 - accuracy: 0.9208
# Epoch 8/10
# 2250/2250 [==============================] - 2s 849us/step - loss: 0.2593 - accuracy: 0.9208
# Epoch 9/10
# 2250/2250 [==============================] - 2s 764us/step - loss: 0.2572 - accuracy: 0.9222
# Epoch 10/10
# 2250/2250 [==============================] - 2s 761us/step - loss: 0.2505 - accuracy: 0.9237
# 563/563 - 0s - loss: 0.3896 - accuracy: 0.7984 - 404ms/epoch - 718us/step
#
# Test accuracy: 0.7984444499015808
#
# Iteration 4
#
# Training data: QPE - 35798. No QPE - 36202.
# Validation data: QPE - 9202. No QPE - 8798.
#
# Epoch 1/10
# 2250/2250 [==============================] - 2s 771us/step - loss: 0.8959 - accuracy: 0.8947
# Epoch 2/10
# 2250/2250 [==============================] - 2s 801us/step - loss: 0.2931 - accuracy: 0.9097
# Epoch 3/10
# 2250/2250 [==============================] - 2s 753us/step - loss: 0.3093 - accuracy: 0.9082
# Epoch 4/10
# 2250/2250 [==============================] - 2s 752us/step - loss: 0.2951 - accuracy: 0.9118
# Epoch 5/10
# 2250/2250 [==============================] - 2s 753us/step - loss: 0.2728 - accuracy: 0.9176
# Epoch 6/10
# 2250/2250 [==============================] - 2s 753us/step - loss: 0.2863 - accuracy: 0.9149
# Epoch 7/10
# 2250/2250 [==============================] - 2s 763us/step - loss: 0.2775 - accuracy: 0.9163
# Epoch 8/10
# 2250/2250 [==============================] - 2s 747us/step - loss: 0.2780 - accuracy: 0.9171
# Epoch 9/10
# 2250/2250 [==============================] - 2s 753us/step - loss: 0.2712 - accuracy: 0.9192
# Epoch 10/10
# 2250/2250 [==============================] - 2s 752us/step - loss: 0.2785 - accuracy: 0.9187
# 563/563 - 0s - loss: 0.3193 - accuracy: 0.8680 - 407ms/epoch - 723us/step
#
# Test accuracy: 0.8679999709129333
#
# Iteration 5
#
# Training data: QPE - 35952. No QPE - 36048.
# Validation data: QPE - 9048. No QPE - 8952.
#
# Epoch 1/10
# 2250/2250 [==============================] - 2s 773us/step - loss: 0.9018 - accuracy: 0.8601
# Epoch 2/10
# 2250/2250 [==============================] - 2s 796us/step - loss: 0.2768 - accuracy: 0.9125
# Epoch 3/10
# 2250/2250 [==============================] - 2s 729us/step - loss: 0.2735 - accuracy: 0.9166
# Epoch 4/10
# 2250/2250 [==============================] - 2s 728us/step - loss: 0.2764 - accuracy: 0.9176
# Epoch 5/10
# 2250/2250 [==============================] - 2s 747us/step - loss: 0.2688 - accuracy: 0.9188
# Epoch 6/10
# 2250/2250 [==============================] - 2s 743us/step - loss: 0.2600 - accuracy: 0.9216
# Epoch 7/10
# 2250/2250 [==============================] - 2s 737us/step - loss: 0.2764 - accuracy: 0.9183
# Epoch 8/10
# 2250/2250 [==============================] - 2s 751us/step - loss: 0.2553 - accuracy: 0.9228
# Epoch 9/10
# 2250/2250 [==============================] - 2s 758us/step - loss: 0.2629 - accuracy: 0.9221
# Epoch 10/10
# 2250/2250 [==============================] - 2s 825us/step - loss: 0.2624 - accuracy: 0.9229
# 563/563 - 0s - loss: 0.2460 - accuracy: 0.9298 - 415ms/epoch - 736us/step
#
# Test accuracy: 0.9297778010368347
