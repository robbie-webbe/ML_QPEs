# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

nqpe_feats = pd.read_csv('no_qpe_feats_dt1000.csv',header=None)
qpe_feats = pd.read_csv('qpe_feats_dt1000.csv',header=None)
real_feats = pd.read_csv('realobs_test_data_dt1000.csv',header=None)

# %%
nqpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  5.000000e+04
# mean       0.050700      0.358708      0.028781      0.000230  4.000000e-07
# std        0.010056      0.051317      0.022863      0.001826  6.324492e-05
# min        0.021564      0.170000      0.000000      0.000000  0.000000e+00
# 25%        0.043510      0.320000      0.010000      0.000000  0.000000e+00
# 50%        0.049710      0.360000      0.030000      0.000000  0.000000e+00
# 75%        0.056800      0.390000      0.050000      0.000000  0.000000e+00
# max        0.116632      0.580000      0.120000      0.040000  1.000000e-02
#
#             5        6             7             8             9   \
# count  50000.0  50000.0  50000.000000  50000.000000  50000.000000
# mean       0.0      0.0      1.483163     -0.002856     -0.637447
# std        0.0      0.0      0.228945      0.404395      0.503596
# ...

# %%
qpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.878225      0.135231      0.057158      0.024597      0.010549
# std        0.448983      0.106088      0.029589      0.019350      0.012097
# min        0.026461      0.010000      0.000000      0.000000      0.000000
# 25%        0.612902      0.060000      0.030000      0.000000      0.000000
# 50%        0.926265      0.110000      0.060000      0.030000      0.000000
# 75%        1.179339      0.170000      0.080000      0.040000      0.020000
# max        2.695636      0.670000      0.160000      0.090000      0.050000
#
#                  5             6             7             8             9   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.004923      0.002556      0.447686      3.162063     14.365558
# ...

# %%
for i in range(14):
    plt.hist(nqpe_feats[i],alpha=0.5,color='b')
    plt.hist(qpe_feats[i],alpha=0.5,color='r')
    plt.show()
