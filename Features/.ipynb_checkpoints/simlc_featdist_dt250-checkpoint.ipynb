# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

nqpe_feats = pd.read_csv('no_qpe_feats_dt250.csv',header=None)
qpe_feats = pd.read_csv('qpe_feats_dt250.csv',header=None)

# %%
nqpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  5.000000e+04
# mean       0.048088      0.357908      0.029236      0.000255  5.000000e-07
# std        0.009509      0.047771      0.021269      0.001631  4.743200e-05
# min        0.022346      0.160000      0.000000      0.000000  0.000000e+00
# 25%        0.041371      0.325000      0.010000      0.000000  0.000000e+00
# 50%        0.047105      0.357500      0.027500      0.000000  0.000000e+00
# 75%        0.053768      0.390000      0.045000      0.000000  0.000000e+00
# max        0.104503      0.580000      0.115000      0.040000  5.000000e-03
#
#             5        6             7             8             9   \
# count  50000.0  50000.0  50000.000000  50000.000000  50000.000000
# mean       0.0      0.0      1.492077      0.001952     -0.626429
# std        0.0      0.0      0.218060      0.398881      0.491320
# ...

# %%
qpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.882875      0.134274      0.056898      0.024530      0.010606
# std        0.447752      0.105205      0.028193      0.018253      0.011342
# min        0.024821      0.002500      0.000000      0.000000      0.000000
# 25%        0.621632      0.060000      0.032500      0.000000      0.000000
# 50%        0.930345      0.107500      0.060000      0.027500      0.005000
# 75%        1.182548      0.170000      0.082500      0.042500      0.022500
# max        2.684939      0.557500      0.122500      0.077500      0.042500
#
#                  5             6             7             8             9   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.004934      0.002529      0.445088      3.237625     15.718944
# ...

# %%
for i in range(14):
    plt.hist(nqpe_feats[i],alpha=0.5,color='b')
    plt.hist(qpe_feats[i],alpha=0.5,color='r')
    plt.show()
