# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

nqpe_feats = pd.read_csv('no_qpe_feats_dt50.csv',header=None)
qpe_feats = pd.read_csv('qpe_feats_dt50.csv',header=None)

# %%
nqpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  5.000000e+04
# mean       0.046720      0.357867      0.029251      0.000273  2.000000e-07
# std        0.009207      0.047152      0.020945      0.001623  2.236001e-05
# min        0.021473      0.172500      0.000000      0.000000  0.000000e+00
# 25%        0.040156      0.326000      0.011500      0.000000  0.000000e+00
# 50%        0.045795      0.357000      0.028000      0.000000  0.000000e+00
# 75%        0.052218      0.389000      0.044500      0.000000  0.000000e+00
# max        0.098561      0.556000      0.110000      0.037500  3.500000e-03
#
#             5        6             7             8             9   \
# count  50000.0  50000.0  50000.000000  50000.000000  50000.000000
# mean       0.0      0.0      1.495495     -0.001231     -0.625429
# std        0.0      0.0      0.216114      0.397801      0.492156
# ...

# %%
qpe_feats.describe()
# Out:
#                  0             1             2             3             4   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.881475      0.134017      0.056946      0.024628      0.010592
# std        0.448980      0.104638      0.028056      0.018250      0.011263
# min        0.024715      0.003500      0.000000      0.000000      0.000000
# 25%        0.618517      0.059500      0.032500      0.001000      0.000000
# 50%        0.928522      0.106500      0.059500      0.026500      0.005500
# 75%        1.180859      0.170000      0.083000      0.043000      0.022000
# max        2.681020      0.530500      0.101000      0.054000      0.030500
#
#                  5             6             7             8             9   \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.004894      0.002521      0.445087      3.241071     15.780987
# ...

# %%
for i in range(14):
    plt.hist(nqpe_feats[i],alpha=0.5,color='b')
    plt.hist(qpe_feats[i],alpha=0.5,color='r')
    plt.show()
