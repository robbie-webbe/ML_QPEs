# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/do19150/Gits/Analysis_Funcs/LC_Sim/')
sys.path.append('/home/do19150/Git_repos/Analysis_Funcs/LC_Sim/')
sys.path.append('/Users/do19150/Gits/Analysis_Funcs/General/')
sys.path.append('/home/do19150/Git_repos/Analysis_Funcs/General/')

from fitsloader import XMMtolc
from CurveFit import GaussCurve
from astropy.modeling.models import Const1D
from stingray.modeling import GaussianLogLikelihood, ParameterEstimation
import matplotlib.pyplot as plt
df = pd.read_csv('eruption_profiles_auto.csv',index_col=0)
df
# Out:
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/stingray/utils.py:24: UserWarning: Numba not installed. Faking it
#   warnings.warn("Numba not installed. Faking it")
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/stingray/largememory.py:25: UserWarning: Large Datasets may not be processed efficiently due to computational constraints
#   warnings.warn(
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/stingray/crossspectrum.py:28: UserWarning: pyfftw not installed. Using standard scipy fft
#   warnings.warn("pyfftw not installed. Using standard scipy fft")
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/stingray/crosscorrelation.py:8: UserWarning: pyfftw not installed. Using standard scipy fft
#   warnings.warn("pyfftw not installed. Using standard scipy fft")
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/stingray/bispectrum.py:10: UserWarning: pyfftw not installed. Using standard scipy fft
# ...

# %%
lc = XMMtolc('Eruption_lcsegs/0124710801_e1.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [25,175,2000,13000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[0,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[0,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0411980401_e1.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [60,80,2000,1300]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[1,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[1,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0823680101_e2.lc',t_bin=10)
lc = lc.rebin(200)  
model = Const1D() + GaussCurve()
start_pars = [50,500,2000,11000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[3,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[3,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0831790701_e1.lc',t_bin=10)
lc = lc.rebin(200)  
model = Const1D() + GaussCurve()
start_pars = [50,450,2000,1000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[4,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[4,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0851180401_e1.lc',t_bin=10)
lc = lc.rebin(200) 
model = Const1D() + GaussCurve()
start_pars = [50,450,2000,20000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[9,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[9,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0851180401_e5.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [50,300,2000,19000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[13,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[13,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0851180501_e1.lc',t_bin=10)
lc = lc.rebin(200)  
model = Const1D() + GaussCurve()
start_pars = [10,300,2000,6000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[14,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[14,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0861910301_e1.lc',t_bin=10)
lc = lc.rebin(200)
#constant countrate at start determined by fitting to first 8ks of segment
model = Const1D(amplitude = 1.25193) + GaussCurve()
model.amplitude_0.fixed=True
start_pars = [150,10000,23000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[18,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[18,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0864560101_e2.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [40,200,2000,13000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[24,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[24,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0872390101_e1.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [10,90,2000,6500]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[31,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[31,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0872390101_e7.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [10,90,2000,2000]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[37,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[37,2] = model.width_1.value

# %%
lc = XMMtolc('Eruption_lcsegs/0893810501_e1.lc',t_bin=10)
lc = lc.rebin(200)
model = Const1D() + GaussCurve()
start_pars = [5,90,2000,0]
loglike = GaussianLogLikelihood(lc.time,lc.counts,lc.counts_err,model)
parest = ParameterEstimation(fitmethod='BFGS', max_post=False)
res = parest.fit(loglike,start_pars,scipy_optimize_options={'options':{'maxiter':100000,'gtol':1e-10 }})
df.iloc[40,1] = model.amplitude_1.value/model.amplitude_0.value
df.iloc[40,2] = model.width_1.value

# %%
df.to_csv('eruption_profiles.csv')

# %%
df
# Out:
#                  Seg   Amplitude      Duration
# 0   0124710801_e1.lc    7.735395   1299.881253
# 1   0411980401_e1.lc    1.099665    710.572857
# 2   0823680101_e1.lc    5.663419   1925.302234
# 3   0823680101_e2.lc    7.598665   2066.117327
# 4   0831790701_e1.lc    6.000399   2047.941361
# 5   0831790701_e2.lc    5.627178   2025.855435
# 6   0831790701_e3.lc    7.140636   2042.675533
# 7   0831790701_e4.lc    5.115359   2075.637888
# 8   0831790701_e5.lc    5.818960   2080.402867
# 9   0851180401_e1.lc   48.437843   1997.023158
# 10  0851180401_e2.lc    7.631581   2185.784021
# 11  0851180401_e3.lc    6.050286   1999.838280
# 12  0851180401_e4.lc    6.218464   2176.778609
# 13  0851180401_e5.lc    6.466084   2235.948897
# 14  0851180501_e1.lc   13.195822   1223.597389
# 15  0851180501_e2.lc   12.028559   1426.344576
# 16  0851180501_e3.lc   17.417195   1245.496028
# 17  0861910201_e1.lc    7.363441   1999.918370
# 18  0861910301_e1.lc  105.431474  18186.558047
# ...
