# %%
import pandas as pd
import os
from scipy.stats import alpha, foldnorm, exponnorm, lognorm, maxwell, rayleigh, skewnorm, truncnorm, norm
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(os.getcwd()[:-25]+'Obs/eruption_profiles.csv',index_col=0)
data = df['Amplitude']
amp_x = np.arange(0,300,0.1)
data.describe()
# Out:
# count     43.000000
# mean      11.191085
# std       16.326156
# min        1.099665
# 25%        6.025343
# 50%        8.413108
# 75%       10.798899
# max      105.431474
# Name: Amplitude, dtype: float64

# %%
dist = alpha.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,alpha.pdf(amp_x,dist[0],dist[1],dist[2]))
plt.xlim(0,25)
# Out:
# (5.9088931729292e-09, -0.0069597385435885475, 3.6528063805344795)
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2606: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# (0.0, 25.0)

# %%
dist = foldnorm.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,foldnorm.pdf(amp_x,dist[0],loc=dist[1],scale=dist[2]))
plt.xlim(0,25)
# Out:
# (0.011854770984704811, 1.0996645153613498, 19.028150970317135)
# (0.0, 25.0)

# %%
dist = exponnorm.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,exponnorm.pdf(amp_x,dist[0],dist[1],dist[2]))
plt.xlim(0,25)
# Out:
# (1243.57911259698, 1.0794467440016975, 0.008062549208019179)
# (0.0, 25.0)

# %%
dist = lognorm.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,lognorm.pdf(amp_x,dist[0],dist[1],dist[2]))
plt.xlim(0,25)
# Out:
# (0.7248586725031487, -0.620252038134596, 8.46543290028486)
# (0.0, 25.0)

# %%
dist = maxwell.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,maxwell.pdf(amp_x,dist[0],dist[1]))
plt.xlim(0,25)
# Out:
# (-16.415468406859716, 18.4613769710328)
# (0.0, 25.0)

# %%
dist = rayleigh.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,rayleigh.pdf(amp_x,dist[0],dist[1]))
plt.xlim(0,25)
# Out:
# (-8.72595392437824, 18.12502556557528)
# (0.0, 25.0)

# %%
dist = skewnorm.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,skewnorm.pdf(amp_x,dist[0],dist[1],dist[2]))
plt.xlim(0,25)
# Out:
# (21982792.077201217, 1.0996602844683991, 19.03103479179326)
# (0.0, 25.0)

# %%
dist = truncnorm.fit(data)
print(dist)
plt.hist(data,bins=[1,4,6,8,11,13,15,20,50,300],density=True)
plt.plot(amp_x,truncnorm.pdf(amp_x,dist[0],dist[1],dist[2],dist[3]))
plt.xlim(0,25)
# Out:
# (0.9015482215897133, 1.6009849280375819, 0.0021890907748951093, 7.134297062689321e-31)
# (0.0, 25.0)
