# %%
import pandas as pd
from scipy.stats import alpha, foldnorm, exponnorm, lognorm, maxwell, rayleigh, skewnorm, truncnorm
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Obs/eruption_dcs.csv',index_col=0)
data = df['DC']
dc_x = np.arange(0,0.5,0.001)
data.describe()
# Out:
# count    8.000000
# mean     0.144557
# std      0.113396
# min      0.074511
# 25%      0.087739
# 50%      0.100277
# 75%      0.133468
# max      0.410000
# Name: DC, dtype: float64

# %%
dist = alpha.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,alpha.pdf(dc_x,dist[0],dist[1],dist[2]))
plt.xlim(0,0.5)
# Out:
# (1.6451625806811952e-05, 0.06180789449146884, 0.02290391520139974)
# /Users/do19150/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2494: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# (0.0, 0.5)

# %%
dist = foldnorm.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,foldnorm.pdf(dc_x,dist[0],loc=dist[1],scale=dist[2]))
plt.xlim(0,0.5)
# Out:
# (9.251842527711524e-05, 0.07451065038674651, 0.12711161895729312)
# (0.0, 0.5)

# %%
dist = exponnorm.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,exponnorm.pdf(dc_x,dist[0],dist[1],dist[2]))
plt.xlim(0,0.5)
# Out:
# (2466.4306803126083, 0.07442088450121698, 2.8181889480796994e-05)
# (0.0, 0.5)

# %%
dist = lognorm.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,lognorm.pdf(dc_x,dist[0],dist[1],dist[2]))
plt.xlim(0,0.5)
# Out:
# (13.359063273767797, 0.07451065038758908, 0.28649658347932083)
# (0.0, 0.5)

# %%
dist = maxwell.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,maxwell.pdf(dc_x,dist[0],dist[1]))
plt.xlim(0,0.5)
# Out:
# (-0.05732422296054009, 0.1316562666170924)
# (0.0, 0.5)

# %%
dist = rayleigh.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,rayleigh.pdf(dc_x,dist[0],dist[1]))
plt.xlim(0,0.5)
# Out:
# (-0.0036666667536883156, 0.1288828394499705)
# (0.0, 0.5)

# %%
dist = skewnorm.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,skewnorm.pdf(dc_x,dist[0],dist[1],dist[2]))
plt.xlim(0,0.5)
# Out:
# (4430890.01854775, 0.07451050943417908, 0.12711515050961064)
# (0.0, 0.5)

# %%
dist = truncnorm.fit(data)
print(dist)
plt.hist(data,bins=10,density=True)
plt.plot(dc_x,truncnorm.pdf(dc_x,dist[0],dist[1],dist[2],dist[3]))
plt.xlim(0,0.5)
# Out:
# (1.0499285683788755, 1.5394839617730116, 0.0022830859442556643, 0.06879280567347346)
# (0.0, 0.5)
